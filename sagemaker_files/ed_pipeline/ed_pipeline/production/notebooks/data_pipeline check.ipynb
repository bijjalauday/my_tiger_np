# %%
import os
import argparse
from ta_pet_id.core.utils import get_package_path
from ta_pet_id.core.base_utils import silence_all_warnings

# %%
import pandas as pd
from ta_pet_id.core.context import create_context as _create_context
from ta_pet_id.pipeline.main import (enroll_pet as _enroll_pet,
                                     infer_pet_id as _infer_pet_id,
                                     train_efficientnet as _train_efficientnet,
                                     train_yolo as _train_yolo)
from ta_pet_id.data_prep import db_utils
from ta_pet_id.data_prep import core
from ta_pet_id.pipeline import yolo, efficientnet
from ta_pet_id.evaluation.report import get_pipeline_eval_report as _get_pipeline_eval_report
# Out:
# ['c:\\users\\uday.bijjala\\cat_visual_id_1\\src\\ta_pet_id'] c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id c:\users\uday.bijjala\cat_visual_id_1\src
# ['c:\\users\\uday.bijjala\\cat_visual_id_1\\src\\ta_pet_id'] c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id c:\users\uday.bijjala\cat_visual_id_1\src
# ['c:\\users\\uday.bijjala\\cat_visual_id_1\\src\\ta_pet_id'] c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id c:\users\uday.bijjala\cat_visual_id_1\src
# ['c:\\users\\uday.bijjala\\cat_visual_id_1\\src\\ta_pet_id'] c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id c:\users\uday.bijjala\cat_visual_id_1\src
# exceptioncannot open resource
# exceptioncannot open resource
# Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)

# %%
def run_enrollment(conf_path, re_enroll=False):
    """Run the enrollment process on given raw pet images data for different households.

    Parameters
    ----------
    conf_path : str
       path of the project's `conf` folder
    re_enroll : bool
      whether to re-enroll the existing enrolled pets or not
      Note: To overwrite existing enrollment, set it to True

    """

    # create the project configuration object
    context_obj = _create_context(conf_path)

    # get list of existing enrolled pets
    enrolled_pets = []
    append_new_pets = False
    if not re_enroll:
        enrolled_pets = db_utils.load_enrolled_pet_db(context_obj)['house_pet_id'].unique()
        append_new_pets = True

    # prepare enroll metadata from the raw image data
    enroll_meta_df = core.prep_enroll_data(context_obj, enrolled_pets)
    if len(enroll_meta_df) == 0:
        raise Warning(f"All the pets from the given enroll data are already enrolled! If you want to re-enroll, "
                      f"run the process again with re_enroll=True.")
    # save enroll metadata to the DB
    db_utils.save_enroll_metadata_db(context_obj, enroll_meta_df, append=append_new_pets)

    # load the trained pipeline models
    eff_net_model = efficientnet.load_model(context_obj)
    yolo_model_objs = yolo.load_model(context_obj)

    # execute enroll process for each house
    house_dfs = []
    for house_id in enroll_meta_df['house_id'].unique():
        house_df = enroll_meta_df[enroll_meta_df['house_id'] == house_id]
        house_pet_db = _enroll_pet(context_obj, house_id, house_df, eff_net_model, yolo_model_objs)
        house_dfs.append(house_pet_db)

    # consolidate households pets into one and save the enrolled pet info to DB
    enrolled_pet_df = pd.concat(house_dfs, ignore_index=True)
    db_utils.save_enrolled_pet_db(context_obj, enrolled_pet_df, append=append_new_pets)
    print("Pet enrollment completed for all houses!")


def run_inference(conf_path, return_eval_report=False):
    """Run the inference process on given raw pet images data for different households.

    Parameters
    ----------
    conf_path : str
       path of the project's `conf` folder
    return_eval_report : bool
      whether to get classification evaluation report or not
      Note: Subject to if truth label instances are provided or not

    Returns
    -------
    report: dict or None
        a report dict if truth labels are provided otherwise None

    """

    # create the project configuration object
    context_obj = _create_context(conf_path)

    # prepare inference metadata from the raw image data
    infer_meta_df = core.prep_inference_data(context_obj)
    # save inference metadata to the DB
    db_utils.save_inference_metadata_db(context_obj, infer_meta_df)

    # load the trained pipeline models
    eff_net_model = efficientnet.load_model(context_obj)
    yolo_model_objs = yolo.load_model(context_obj)

    # load enrolled pets db
    enrolled_pets_db = db_utils.load_enrolled_pet_db(context_obj)
    enrolled_houses = enrolled_pets_db['house_id'].unique()

    # execute inference process for each house
    house_dfs = []
    for house_id in infer_meta_df['house_id'].unique():
        if house_id not in enrolled_houses:
            # as no pets are enrolled from this house, inference can't be given for the same
            continue
        house_df = infer_meta_df[infer_meta_df['house_id'] == house_id]
        house_df_preds = _infer_pet_id(context_obj, house_id, house_df, enrolled_pets_db, eff_net_model,
                                       yolo_model_objs)
        house_dfs.append(house_df_preds)

    # consolidate households pets into one and save the inference data predictions to DB
    inference_preds_df = pd.concat(house_dfs, ignore_index=True)
    db_utils.save_inference_prediction_db(context_obj, inference_preds_df)

    # select the inference data for which truth label are given and generate evaluation report
    eval_df = inference_preds_df[inference_preds_df['pet_type'].notnull() &
                                 inference_preds_df['pet_id'].notnull()]
    if len(eval_df) > 0:
        report_path = context_obj.data_catalog['inference']['inference_preds_report'].format(
            **context_obj.data_catalog['inference'])
        report = _get_pipeline_eval_report(eval_df, return_report=return_eval_report, write_report=True,
                                           report_path=report_path)
    if return_eval_report:
        return report


def train_efficientnet_model(conf_path):
    """Run the EfficientNetB2 training process on given raw pet images data for different households.

    Parameters
    ----------
    conf_path : str
       path of the project's `conf` folder

    """

    # create the project configuration object
    context_obj = _create_context(conf_path)

    # prepare train meta data from the raw image data
    train_meta_df = core.prep_efficientnet_train_metadata(context_obj)
    db_utils.save_efficientnet_train_metadata_db(context_obj, train_meta_df)

    # run efficientnet training process
    _train_efficientnet(context_obj, train_meta_df)


def train_yolo_model(conf_path):
    """Run the YOLOv5 training process on given raw pet images data for different households.

    Parameters
    ----------
    conf_path : str
       path of the project's `conf` folder

    """

    # create the project configuration object
    context_obj = _create_context(conf_path)

    # prepare train meta data from the raw image data
    train_meta_df = core.prep_yolo_train_metadata(context_obj)
    db_utils.save_yolo_train_metadata_db(context_obj, train_meta_df)

    # run yolo training process
    _train_yolo(context_obj, train_meta_df)

# %%
# changed the yolo local yaml for using nano tflite model

config_path = os.path.join(get_package_path(), "../production/conf/config.yml")
# Out:
# ['c:\\users\\uday.bijjala\\cat_visual_id_1\\src\\ta_pet_id'] c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id c:\users\uday.bijjala\cat_visual_id_1\src

# %%
config_path
# Out:
# 'c:\\users\\uday.bijjala\\cat_visual_id_1\\src\\../production/conf/config.yml'

# %%
run_enrollment(config_path, re_enroll=True)
# Out:
# Initialized Random Seed : 0
# Context created from c:\users\uday.bijjala\cat_visual_id_1\src\../production/conf/config.yml
# Package version : 1.0.0
# <fsspec.implementations.local.LocalFileSystem object at 0x00000296997CF040> ['c:/users/uday.bijjala/cat_visual_id_1/src/../production/conf/config.yml']
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.41it/s]
# c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id\data_prep\db_utils.py:9: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   db.to_excel(db_path, index=False)
# Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_2077924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_2082068) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_2102657) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_2104860) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_2107608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_2114820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_2112069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_2104187) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_2079187) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_2107026) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_2108452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_2111810) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_2114384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_2113606) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_2079584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_2081793) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_2108386) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_2082109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_2108215) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_2110160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_2082333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_2107285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_2105812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_2106419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_2115057) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_2102591) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_2112003) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_2079411) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_2105423) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference__wrapped_model_2067898) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_2080564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_model_layer_call_and_return_conditional_losses_2099778) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_2082725) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_2115380) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_2080024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_2102998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_2078978) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_2080472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_2105983) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_2081180) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_2105230) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_2102420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_2079452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_2079360) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_2082465) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_2078355) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_2082557) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_2081844) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_2079642) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_2080732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_2081661) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_2080340) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_2081411) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_2103434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_2078564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_2079851) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_2113170) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_2103693) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_2112629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_2081885) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_2081452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_2113236) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_2104253) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_2114213) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_2113843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_2082241) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_2081569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_2080299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_2104794) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_2082292) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_2081353) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_2114991) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_2078314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_2080248) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_2078124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_2080956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_2080997) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_2080075) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_model_layer_call_and_return_conditional_losses_2102232) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_2078083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_2103064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_2103627) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_2109989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_2106656) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_2078472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_2080905) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_2082674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_2114450) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_2078696) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_2078920) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_2109600) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_2078747) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_2079136) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_2082017) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_2080681) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_2109666) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_2081129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_2081620) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_2104623) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_2106590) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_2080116) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_2111374) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_2079892) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_2112392) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_2082516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_2107779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_2109059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_2110226) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_2107219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_2078788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_2113777) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_2079019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_2104016) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_2112563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_2106049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_2110833) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_2110767) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_2112999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_2080523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_2111203) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_2077965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_2078256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_2115551) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_2078523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_2079800) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_2108822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_2081221) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_2108993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_2080773) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_2079683) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_2109429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_2077873) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_2079228) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_2111440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_2107845) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_2110596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_2105489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# some other extension
# some other extension
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_enrollment(config_path, re_enroll=True)
#
# Cell In[3], line 40, in run_enrollment(conf_path, re_enroll)
#      38 for house_id in enroll_meta_df['house_id'].unique():
#      39     house_df = enroll_meta_df[enroll_meta_df['house_id'] == house_id]
# ---> 40     house_pet_db = _enroll_pet(context_obj, house_id, house_df, eff_net_model, yolo_model_objs)
#      41     house_dfs.append(house_pet_db)
#      43 # consolidate households pets into one and save the enrolled pet info to DB
#
# File c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id\pipeline\main.py:55, in enroll_pet(context, house_id, house_df, efficientnet_model, yolo_model_objs)
#      52 imgs_count = len(img_paths)
#      53 pet_imgs = [cv2.imread(os.path.join(enroll_dir_path, img_path)) for img_path in img_paths]
# ---> 55 pred_pet_classes, pred_pet_coords, pred_pet_faces = yolo.predict(context, pet_imgs, yolo_model_objs)
#      58 pred_pet_valid_faces = list(filter(lambda x: x is not None, pred_pet_faces))
#      60 min_imgs_required = context.data_catalog['enroll']['min_imgs_required']
#
# File c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id\pipeline\yolo.py:72, in predict(context, img_array, model_objs)
#      68 iou_thresh = context.yolo['scoring']['iou_threshold']
#      70 model, device = model_objs
# ---> 72 output = _yolo_detect(model, device, img_array, imgsz=[256,256],
#      73                       conf_thres=conf_thresh, iou_thres=iou_thresh)
#      75 return output
#
# File c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id\yolo\detect.py:67, in yolo_detect(model, device, img_array, imgsz, conf_thres, iou_thres, filter_class, max_det, half)
#      64 dt[0] += t2 - t1
#      66 # Inference
# ---> 67 pred = model(im, augment=False, visualize=False)
#      68 t3 = time_sync()
#      69 dt[1] += t3 - t2
#
# File c:\Users\uday.bijjala\Miniconda3\envs\npp-pet-id_1-dev\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id\yolo\models\common.py:288, in DetectMultiBackend.forward(self, im, augment, visualize, val)
#     286 else:  # TensorFlow model (TFLite, pb, saved_model)
#     287     print('some other extension')
# --> 288 y = torch.tensor(y) if isinstance(y, np.ndarray) else y
#     289 return (y, []) if val else y
#
# UnboundLocalError: local variable 'y' referenced before assignment

# %%
run_inference(config_path)
# Out:
# Initialized Random Seed : 0
# Context created from c:\users\uday.bijjala\cat_visual_id_1\src\../production/conf/config.yml
# Package version : 1.0.0
# <fsspec.implementations.local.LocalFileSystem object at 0x00000257ACE5F040> ['c:/users/uday.bijjala/cat_visual_id_1/src/../production/conf/config.yml']
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:10<00:00, 10.22s/it]
# c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id\data_prep\db_utils.py:9: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   db.to_excel(db_path, index=False)
# Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_2077924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_2082068) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_2102657) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_2104860) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_2107608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_2114820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_2112069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_2104187) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_2079187) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_2107026) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_2108452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_2111810) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_2114384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_2113606) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_2079584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_2081793) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_2108386) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_2082109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_2108215) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_2110160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_2082333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_2107285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_2105812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_2106419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_2115057) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_2102591) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_2112003) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_2079411) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_2105423) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference__wrapped_model_2067898) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_2080564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_model_layer_call_and_return_conditional_losses_2099778) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_2082725) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_2115380) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_2080024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_2102998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_2078978) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_2080472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_2105983) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_2081180) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_2105230) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_2102420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_2079452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_2079360) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_2082465) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_2078355) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_2082557) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_2081844) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_2079642) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_2080732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_2081661) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_2080340) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_2081411) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_2103434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_2078564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_2079851) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_2113170) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_2103693) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_2112629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_2081885) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_2081452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_2113236) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_2104253) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_2114213) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_2113843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_2082241) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_2081569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_2080299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_2104794) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_2082292) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_2081353) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_2114991) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_2078314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_2080248) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_2078124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_2080956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_2080997) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_2080075) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_model_layer_call_and_return_conditional_losses_2102232) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_2078083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_2103064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_2103627) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_2109989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_2106656) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_2078472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_2080905) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_2082674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_2114450) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_2078696) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_2078920) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_2109600) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_2078747) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_2079136) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_2082017) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_2080681) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_2109666) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_2081129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_2081620) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_2104623) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_2106590) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_2080116) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_2111374) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_2079892) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_2112392) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_2082516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_2107779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_2109059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_2110226) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_2107219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_2078788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_2113777) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_2079019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_2104016) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_2112563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_2106049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_2110833) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_2110767) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_2112999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_2080523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_2111203) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_2077965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_2078256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_2115551) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_2078523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_2079800) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_2108822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_2081221) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_2108993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_2080773) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_2079683) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_2109429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_2077873) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_2079228) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_2111440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_2107845) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_2110596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_2105489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# c:\users\uday.bijjala\cat_visual_id_1\src\ta_pet_id\data_prep\db_utils.py:9: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   db.to_excel(db_path, index=False)

# %%
import pandas as pd
df=pd.read_excel("C:/Users/uday.bijjala/cat_visual_id-master/cat_visual_id-master/data/processed/inference_data/inference_preds_db.xlsx")
df.head()
# Out:
#               datetime house_id                image_path  pet_type  pet_id  \
# 0  29-06-2023 17:10:17  house_1          house_1\0022.png       NaN     NaN
# 1  29-06-2023 17:10:17  house_1     house_1\548152648.jpg       NaN     NaN
# 2  29-06-2023 17:10:17  house_1     house_1\548152654.jpg       NaN     NaN
# 3  29-06-2023 17:10:17  house_2  house_2\00000156_008.jpg       NaN     NaN
# 4  29-06-2023 17:10:17  house_2  house_2\00000182_017.jpg       NaN     NaN
#
#     pred_pet_type           pred_pet_id
# 0             cat                  Anne
# 1             cat                  Anne
# 2             cat                  Anne
# 3  ['cat', 'cat']  [['coff', 'Coffee']]
# 4             cat                Coffee

# %%
def ip(x):
    if "fable" in x:
        return 0
    if "fauna" in x:
        return 1
    if "oak" in x:
        return 2
    if "first" in x: 
        return 3
    if "sparkler" in x:
        return 4
    if "tardis" in x:
        return 5
df["image_path1"]=df["image_path"].apply(ip)

# %%
def ip(x):
    if "fable" in x:
        return 0
    if "fauna" in x:
        return 1
    if "oak" in x:
        return 2
    if "new_image" in x: 
        return 3
    if "sparkler" in x:
        return 4
    if "tardis" in x:
        return 5
df["pred_pet_id_1"]=df["pred_pet_id"].apply(ip)

# %%
from sklearn.metrics import classification_report,confusion_matrix 

print(classification_report(df["image_path1"],df["pred_pet_id_1"]))
print(confusion_matrix(df["image_path1"],df["pred_pet_id_1"]))
