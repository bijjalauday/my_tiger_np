# %%
# Detection on 120 epoch model

# !python detect.py --weights "extra_dogs-fp16.tflite" --source "D:/cat_id/test/yolo_test/images" --data train_data.yaml --img-size 256 --conf-thres 0.4 --iou-thres 0.4 --save-txt --save-conf

# python detect.py --weights yolo_side_detection_4.pt --source "D:/cat_id/Top5frames/eyes_nose_analysis/inference images from nic videos croped/inference images from nic videos croped" --data train_data1.yaml --img-size 256 --conf-thres 0.4 --iou-thres 0.4 --save-txt --save-conf
# Out:
# detect: weights=['extra_dogs-fp16.tflite'], source=D:/cat_id/test/yolo_test/images, data=train_data.yaml, imgsz=[256, 256], conf_thres=0.4, iou_thres=0.4, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-247-g3f02fde Python-3.10.11 torch-2.0.1+cpu CPU
#
# Loading extra_dogs-fp16.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# image 1/7000 D:\cat_id\test\yolo_test\images\00000001_012.jpg: 256x256 1 cat, 20.8ms
# image 2/7000 D:\cat_id\test\yolo_test\images\00000001_027.jpg: 256x256 1 cat, 17.3ms
# image 3/7000 D:\cat_id\test\yolo_test\images\00000001_029.jpg: 256x256 1 cat, 10.7ms
# ...

# %%
import os 
import subprocess 
for i in os.listdir("D:/cat_id/natalie_shared_videos/OneDrive_2023-11-14-PTC_approach_11-9-2023/PTC_approach_11-9-2023/"):
    command=f"python detect.py --weights D:/cat_id/yolov5_training_sharing/extra_dogs-fp16.tflite --source D:/cat_id/natalie_shared_videos/OneDrive_2023-11-14-PTC_approach_11-9-2023/PTC_approach_11-9-2023/{i}/ --data train_data.yaml --img-size 256 --conf-thres 0.4 --iou-thres 0.4 --save-txt --save-conf"
    subprocess.run(command, shell=True, check=True)

# %%
# export to tflite

# !python export.py --weights extra_dogs.pt --data train_data.yaml --imgsz 256 256 --include tflite
# Out:
# Model: "model"
# export: data=train_data.yaml, weights=['extra_dogs.pt'], imgsz=[256, 256], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5  v7.0-247-g3f02fde Python-3.10.11 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from extra_dogs.pt with output shape (1, 4032, 7) (3.5 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.8.0...
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
# ...
